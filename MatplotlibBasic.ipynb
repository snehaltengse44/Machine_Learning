# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6,7,8]
y=[10,20,30,23,35,31,11,23]
x1=[5,15,25,35,45,55,65]
y1=[12,45,22,54,67,79,56]

# %%
plt.xlabel("days")
plt.ylabel("temp")
plt.plot(x,y,color="black",linestyle='dashdot',marker='D',linewidth="2")
plt.plot(x1,y1,animated=False)
