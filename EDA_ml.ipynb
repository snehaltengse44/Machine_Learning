# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("train.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.read_csv("train.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
df.shape

# %%
df.info()

# %%
df.sample(10)

# %%
df.isnull().sum()

# %%
#sns.countplot(x="Pclass")
sns.countplot(x="Pclass",data=df)
plt.show()

# %%
plt.hist(df['Age'])

# %%
sns.displot(df["Age"],kind="kde")
plt.show()
# on y axis it it showing the probability of each range or x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sns.displot(df["Age"],kind="kde")
#       2 plt.show()
#
# NameError: name 'df' is not defined

# %%
sns.boxplot(df['Age'])

# %%
sns.boxplot(df['Fare'])

# %%
sns.scatterplot(x=df['Age'],y=df['Fare'])

# %%
sns.scatterplot(x=df['Age'],y=df['Fare'],hue=df['Sex'])

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 13            14         0       3    Andersson, Mr. Anders Johan    male
# 789          790         0       1       Guggenheim, Mr. Benjamin    male
# 395          396         0       3            Johansson, Mr. Erik    male
# 32            33         1       3       Glynn, Miss. Mary Agatha  female
# 627          628         1       1  Longley, Miss. Gretchen Fiske  female
#
#       Age  SibSp  Parch    Ticket     Fare    Cabin Embarked
# 13   39.0      1      5    347082  31.2750      NaN        S
# 789  46.0      0      0  PC 17593  79.2000  B82 B84        C
# 395  22.0      0      0    350052   7.7958      NaN        S
# 32    NaN      0      0    335677   7.7500      NaN        Q
# 627  21.0      0      0     13502  77.9583       D9        S

# %%
sns.scatterplot(x=df['Age'],y=df['Fare'],hue=df["Sex"],style=df["Survived"],size=df["Pclass"])
# ploting more than 2 parameters in one graph
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
#to findout what is an avg age of each Pclass using BAR PLOT
sns.barplot(x=df['Pclass'],y=df['Fare'],hue=df['Sex'])
# hue always divide the single data set into 2 parts like Pclass divide into 2 parts
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.boxplot(x=df['Sex'],y=df['Age'],hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.heatmap(pd.crosstab(df['Survived'],df['Pclass']))
#or pd.pivote_table(values="jo values show karni hia",column="___",index="  ")
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
#Cluster map talk about the closeness with in the values
sns.clustermap(pd.crosstab(df['Survived'],df["Age"]))

# %%
#pairplot=collection of scatter plot , it detechs the row and draw a scatterplot in between possible row
sns.pairplot(df,hue='Pclass')

# %%
#lineplot(numerical vs numerical)
#if x-axis par time ka function ho as like time , month etc
new=df.groupby(df['Pclass']).sum()
new
# Out:
#         PassengerId  Survived  \
# Pclass
# 1             99705       136
# 2             82056        87
# 3            215625       119
#
#                                                      Name  \
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...
# 3       Braund, Mr. Owen HarrisHeikkinen, Miss. LainaA...
#
#                                                       Sex      Age  SibSp  \
# Pclass
# 1       femalefemalemalefemalemalemalemalefemalemalema...  7111.42     90
# 2       femalefemalemalemalemalemalefemalefemalefemale...  5168.83     74
# 3       malefemalemalemalemalefemalefemalemalemalefema...  8924.92    302
#
#         Parch                                             Ticket        Fare  \
# Pclass
# 1          77  PC 175991138031746311378311378819950PC 17601PC...  18177.4125
# 2          70  237736248706244373239865248698C.A. 2457911668S...   3801.8417
# ...

# %%
sns.lineplot(new['Pclass'],new['Fare'])
#there should be time function at x axis
# Out:
#   Cell In[49], line 1
#     sns.lineplot(x=new['Pclass'],new['Fare'])
#                                             ^
# SyntaxError: positional argument follows keyword argument
